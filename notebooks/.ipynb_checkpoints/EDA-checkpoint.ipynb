# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Replace 'your_file.csv' with the actual name of the downloaded file
df = pd.read_csv('data/raw/complaints.csv', low_memory=False)

# Let's see the first few rows
print(df.head())

# Check how many complaints and columns we have
print(f"Total complaints: {df.shape[0]}")
